# %% [markdown]
# ### Import Libraries

# %%
import sys
sys.path.insert(1, '../scripts')
import extended_model
import analysis_helper
import importlib
import glob
import json
importlib.reload(extended_model)
importlib.reload(analysis_helper)

import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

import numpy as np
import bisect
import itertools

from functools import reduce
from operator import mul
from scipy.stats import norm
import random
from math import comb

import multiprocessing as mp

from tqdm import tqdm
from distinctipy import get_colors
from sklearn.cluster import DBSCAN

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 14

# %% [markdown]
# ## Run the simulations
# With 4 nodes and changing q values

# %%
pool = mp.Pool(processes=32)

folder = 'increased_node_count'
simulation_count = 100
n_nodes = 4
N = 300
p = .2
q = .4
params = [*zip([*range(simulation_count)], [n_nodes]*simulation_count, [N]*simulation_count, [p]*simulation_count, [q]*simulation_count)]

results = pool.starmap(extended_model.simulate_rewiring, params)
graphs = [r[1] for r in results]
results = {sim_no:track for sim_no,track in [r[0] for r in results]}
# Out:
#   3%|▎         | 13459/432001 [01:22<30:45:09,  3.78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 q = .4
#       9 params = [*zip([*range(simulation_count)], [n_nodes]*simulation_count, [N]*simulation_count, [p]*simulation_count, [q]*simulation_count)]
# ---> 11 results = pool.starmap(extended_model.simulate_rewiring, params)
#      12 graphs = [r[1] for r in results]
#      13 results = {sim_no:track for sim_no,track in [r[0] for r in results]}
#
# File /media/volume/data/miniconda3/envs/prosocial/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /media/volume/data/miniconda3/envs/prosocial/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /media/volume/data/miniconda3/envs/prosocial/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /media/volume/data/miniconda3/envs/prosocial/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /media/volume/data/miniconda3/envs/prosocial/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
#   3%|▎         | 14041/432001 [01:24<12:39, 550.65it/s]
#   5%|▍         | 19921/432001 [02:11<11:53, 577.82it/s]]

# %% [markdown]
# ## Analysis of One Simulation

# %%
i = 44
track = results[i]
analysis_helper.overall_analysis(n_nodes, track, folder=folder, i=i, save=False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
